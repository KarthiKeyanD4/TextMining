# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rb') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rb') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    
    precision = len(gold.intersection(pred))/len(pred)
    recall = len(gold.intersection(pred))/len(gold)
    f1 = 2*(precision*recall)/(precision+recall)
    
    print(f"The precision value is {precision}")
    print(f"The recall value is {recall}")
    print(f"The f1 score is {f1}")

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# The precision value is 0.6
# The recall value is 1.0
# The f1 score is 0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield (row.sentence_id, row.beg, row.end)

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
dev_gold = list(gold_spans(df_dev))

# %%
print(f"The first triple is {dev_gold[0]}")
# Out:
# The first triple is ('0946-000', 2, 3)

# %%
print(f"The last triple is {dev_gold[len(dev_gold)-1]}")
# Out:
# The last triple is ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(f"The total unique triples is {len(spans_dev_gold)}")
# Out:
# The total unique triples is 5917

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy NER on the development data
pred = list()
for row in df_dev.sentence_id:
    sentence = df_dev.loc[df_dev.sentence_id == row, "sentence"].values[0]
    doc = nlp(sentence) 
    for ent in doc.ents:
        index = row,ent.start, ent.end
        pred.append(index)

# %%
evaluation_report(spans_dev_gold,set(pred))
# Out:
# The precision value is 0.5342805005213764
# The recall value is 0.6927497042420145
# The f1 score is 0.6032820663772168

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis
error_rport = error_report(df_dev[:500],spans_dev_gold,set(pred))
# Out:
# Sentence: CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTER INNINGS VICTORY .
#   FN: LEICESTERSHIRE
# Sentence: West Indian all-rounder Phil Simmons took four for 38 on Friday as Leicestershire beat Somerset by an innings and 39 runs in two days to take over at the head of the county championship .
#   FP: four
#   FP: 38
#   FP: Friday
#   FP: 39
#   FP: two days
#   FN: Somerset
# Sentence: Their stay on top , though , may be short-lived as title rivals Essex , Derbyshire and Surrey all closed in on victory while Kent made up for lost time in their rain-affected match against Nottinghamshire .
#   FN: Nottinghamshire
# Sentence: After bowling Somerset out for 83 on the opening morning at Grace Road , Leicestershire extended their first innings by 94 runs before being bowled out for 296 with England discard Andy Caddick taking three for 83 .
#   FP: first
#   FP: 83
#   FP: 94
#   FP: 296
#   FP: the opening morning
#   FP: three
#   FP: 83
#   FN: Leicestershire
# Sentence: Trailing by 213 , Somerset got a solid start to their second innings before Simmons stepped in to bundle them out for 174 .
#   FP: 213
#   FP: second
#   FP: 174
# Sentence: Essex , however , look certain to regain their top spot after Nasser Hussain and Peter Such gave them a firm grip on their match against Yorkshire at Headingley .
#   FN: Essex
# Sentence: Hussain , considered surplus to England 's one-day requirements , struck 158 , his first championship century of the season , as Essex reached 372 and took a first innings lead of 82 .
#   FP: 372
#   FP: 82
#   FP: one-day
#   FP: first
#   FP: 158
#   FP: first championship century of the season
# Sentence: By the close Yorkshire had turned that into a 37-run advantage but off-spinner Such had scuttled their hopes , taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain .
#   FP: 24
#   FP: 48
#   FP: 119
#   FP: five
#   FP: four
#   FP: 37-run
#   FN: Such
# Sentence: At the Oval , Surrey captain Chris Lewis , another man dumped by England , continued to silence his critics as he followed his four for 45 on Thursday with 80 not out on Friday in the match against Warwickshire .
#   FP: 80
#   FP: Thursday
#   FP: four
#   FP: Friday
#   FN: Warwickshire
#   FN: Oval
# Sentence: He was well backed by England hopeful Mark Butcher who made 70 as Surrey closed on 429 for seven , a lead of 234 .
#   FP: 70
#   FP: seven
#   FP: 429
#   FP: 234
# Sentence: Derbyshire kept up the hunt for their first championship title since 1936 by reducing Worcestershire to 133 for five in their second innings , still 100 runs away from avoiding an innings defeat .
#   FP: 100
#   FP: five
#   FP: second
#   FP: first
#   FP: 133
#   FP: 1936
#   FN: Derbyshire
# Sentence: Australian Tom Moody took six for 82 but Chris Adams , 123 , and Tim O'Gorman , 109 , took Derbyshire to 471 and a first innings lead of 233 .
#   FP: six
#   FP: first
#   FP: 82
#   FP: 471
#   FP: 123
#   FP: 109
#   FP: 233
# Sentence: After the frustration of seeing the opening day of their match badly affected by the weather , Kent stepped up a gear to dismiss Nottinghamshire for 214 .
#   FP: 214
#   FP: the opening day
# Sentence: They were held up by a gritty 84 from Paul Johnson but ex-England fast bowler Martin McCague took four for 55 .
#   FP: four
#   FP: 84
#   FP: 55
# Sentence: By stumps Kent had reached 108 for three .
#   FP: 108
#   FP: three
# Sentence: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES .
#   FN: ENGLISH COUNTY CHAMPIONSHIP
# Sentence: Result and close of play scores in English county championship matches on Friday :
#   FP: Friday
# Sentence: Leicester : Leicestershire beat Somerset by an innings and 39 runs .
#   FP: 39
#   FN: Leicestershire
#   FN: Somerset
#   FN: Leicester
# Sentence: Somerset 83 and 174 ( P. Simmons 4-38 ) , Leicestershire 296 .
#   FP: 174
#   FP: 296
#   FN: P. Simmons
#   FN: Leicestershire
# Sentence: Leicestershire 22 points , Somerset 4 .
#   FP: 22
#   FN: Leicestershire
# Sentence: Chester-le-Street : Glamorgan 259 and 207 ( A. Dale 69 , H. Morris 69 ; D. Blenkiron 4-43 ) , Durham 114 ( S. Watkin 4-28 ) and 81-3 .
#   FP: 81-3
#   FP: 259
#   FP: 207
#   FP: Durham 114
#   FN: A. Dale
#   FN: Durham
#   FN: S. Watkin
#   FN: Glamorgan
#   FN: Chester-le-Street
# Sentence: Tunbridge Wells : Nottinghamshire 214 ( P. Johnson 84 ; M. McCague 4-55 ) , Kent 108-3 .
#   FP: M. McCague 4-55
#   FP: P. Johnson 84
#   FP: 214
#   FN: Kent
#   FN: M. McCague
#   FN: Tunbridge Wells
#   FN: Nottinghamshire
#   FN: P. Johnson
# Sentence: London ( The Oval ) : Warwickshire 195 , Surrey 429-7 ( C. Lewis 80 not out , M. Butcher 70 , G. Kersey 63 , J. Ratcliffe 63 , D. Bicknell 55 ) .
#   FP: 195
#   FP: 55
#   FP: J. Ratcliffe 63
#   FN: Warwickshire
#   FN: Surrey
#   FN: C. Lewis
#   FN: J. Ratcliffe
# Sentence: Hove : Sussex 363 ( W. Athey 111 , V. Drakes 52 ; I. Austin 4-37 ) , Lancashire 197-8 ( W. Hegg 54 )
#   FP: 52
#   FP: I. Austin 4-37
#   FP: 363
#   FP: 111
#   FN: I. Austin
#   FN: Lancashire
#   FN: Hove
#   FN: Sussex
# Sentence: Portsmouth : Middlesex 199 and 426 ( J. Pooley 111 , M. Ramprakash 108 , M. Gatting 83 ) , Hampshire 232 and 109-5 .
#   FP: 426
#   FP: 232
#   FP: 108
#   FP: 199
#   FP: J. Pooley 111
#   FN: J. Pooley
#   FN: Hampshire
#   FN: Portsmouth
#   FN: Middlesex
# Sentence: Chesterfield : Worcestershire 238 and 133-5 , Derbyshire 471 ( J. Adams 123 , T.O'Gorman 109 not out , K. Barnett 87 ; T. Moody 6-82 )
#   FP: K. Barnett 87
#   FP: 238
#   FP: T. Moody 6-82
#   FP: J. Adams 123
#   FP: T.O'Gorman 109
#   FN: T. Moody
#   FN: K. Barnett
#   FN: Worcestershire
#   FN: Derbyshire
#   FN: J. Adams
#   FN: T.O'Gorman
# Sentence: Bristol : Gloucestershire 183 and 185-6 ( J. Russell 56 not out ) , Northamptonshire 190 ( K. Curran 52 ; A. Smith 5-68 ) .
#   FP: A. Smith 5-68
#   FP: 183
#   FP: J. Russell 56
#   FP: Northamptonshire 190
#   FN: Northamptonshire
#   FN: K. Curran
#   FN: A. Smith
#   FN: Bristol
#   FN: Gloucestershire
#   FN: J. Russell
# Sentence: CRICKET - 1997 ASHES INTINERARY .
#   FP: 1997
#   FN: ASHES
# Sentence: Australia will defend the Ashes in
#   FN: Ashes
# Sentence: starting on May 13 next year , the Test and County Cricket Board
#   FP: May 13 next year
#   FP: County Cricket Board
#   FP: Test
#   FN: Test and County Cricket Board
# Sentence: Australia will also play three one-day internationals and
#   FP: three
# Sentence: English county sides and another against British Universities ,
#   FP: British
#   FN: British Universities
# Sentence: as well as one-day matches against the Minor Counties and
#   FN: Minor Counties
# Sentence: May 13 Arrive in London
#   FP: May 13
# Sentence: May 14 Practice at Lord 's
#   FP: May 14 Practice
#   FN: Lord 's
# Sentence: May 15 v Duke of Norfolk 's XI ( at Arundel )
#   FP: May 15
#   FN: Duke of Norfolk 's XI
#   FN: Arundel
# Sentence: May 17 v Northampton
#   FP: May 17
# Sentence: May 18 v Worcestershire
#   FP: May 18
# Sentence: May 20 v Durham
#   FP: May 20
#   FN: Durham
# Sentence: May 22 First one-day international ( at Headingley ,
#   FP: May 22 First
# Sentence: Leeds )
#   FN: Leeds
# Sentence: May 24 Second one-day international ( at The Oval ,
#   FP: one-day
#   FP: May 24 Second
#   FN: The Oval
# Sentence: May 25 Third one-day international ( at Lord 's , London )
#   FP: one-day
#   FP: May 25 Third
#   FN: Lord 's
# Sentence: May 27-29 v Gloucestershire or Sussex or Surrey ( three
#   FP: May 27-29
#   FP: three
#   FN: Sussex
#   FN: Gloucestershire
# Sentence: May 31 - June 2 v Derbyshire ( three days )
#   FP: May 31 - June 2
#   FP: three days
#   FN: Derbyshire
# Sentence: June 5-9 First test match ( at Edgbaston , Birmingham )
#   FP: June 5-9
#   FP: First
# Sentence: June 14-16 v Leicestershire ( three days )
#   FP: June 14-16
#   FP: three days
#   FN: Leicestershire
# Sentence: June 19-23 Second test ( at Lord 's )
#   FP: June 19-23
#   FP: Second
#   FN: Lord 's
# Sentence: June 25-27 v British Universities ( at Oxford , three days )
#   FP: June 25-27
#   FP: three days
#   FP: British
#   FN: British Universities
# Sentence: June 28-30 v Hampshire ( three days )
#   FP: June 28-30
#   FP: three days
#   FN: Hampshire
# Sentence: July 3-7 Third test ( at Old Trafford , Manchester )
#   FP: July 3-7 Third
#   FP: Trafford
#   FN: Old Trafford
# Sentence: July 9 v Minor Counties XI
#   FP: July 9
#   FN: Minor Counties XI
# Sentence: July 12 v Scotland
#   FP: July 12
# Sentence: July 16-18 v Glamorgan ( three days )
#   FP: three days
#   FP: July 16-18
# Sentence: July 19-21 v Middlesex ( three days )
#   FP: July 19-21
#   FP: three days
#   FN: Middlesex
# Sentence: July 24-28 Fourth test ( at Headingley )
#   FP: July
#   FP: 24-28 Fourth
# Sentence: August 1-4 v Somerset ( four days )
#   FP: August 1-4
#   FP: four days
# Sentence: August 7-11 Fifth test ( at Trent Bridge , Nottingham )
#   FP: August 7-11
#   FP: Fifth
# Sentence: August 16-18 v Kent ( three days )
#   FP: three days
#   FP: August 16-18
# Sentence: August 21-25 Sixth test ( at The Oval , London ) .
#   FP: August
#   FP: Sixth
#   FN: The Oval
# Sentence: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN .
#   FP: ENGLAND CAPTAIN
#   FN: SHEARER
#   FN: ENGLAND
# Sentence: The world 's costliest footballer Alan Shearer was named as the new England captain on Friday .
#   FP: Friday
# Sentence: The 26-year-old , who joined Newcastle for 15 million pounds sterling ( $ 23.4 million ) , takes over from Tony Adams , who led the side during the European championship in June , and former captain David Platt .
#   FP: 15 million pounds
#   FP: $ 23.4 million
#   FP: June
# Sentence: Adams and Platt are both injured and will miss England 's opening World Cup qualifier against Moldova on Sunday .
#   FP: Sunday
#   FN: Adams
# Sentence: Shearer takes the captaincy on a trial basis , but new coach Glenn Hoddle said he saw no reason why the former Blackburn and Southampton skipper should not make the post his own .
#   FN: Shearer
# Sentence: " I 'm sure there wo n't be a problem , I 'm sure Alan is the man for the job , " Hoddle said .
#   FN: Hoddle
# Sentence: " There were three or four people who could have done it but when I spoke to Alan he was up for it and really wanted it .
#   FP: three
#   FP: four
# Sentence: Shearer 's Euro 96 striking partner Teddy Sheringham withdrew from the squad with an injury on Friday .
#   FP: Friday
# Sentence: BELGRADE 1996-08-30
#   FP: 1996-08-30
#   FN: BELGRADE
# Sentence: Red Star ( Yugoslavia ) beat Dinamo ( Russia ) 92-90 ( halftime
#   FP: 92-90
# Sentence: SOCCER - ROMANIA BEAT LITHUANIA IN UNDER-21 MATCH .
#   FP: SOCCER - ROMANIA BEAT LITHUANIA
#   FN: LITHUANIA
#   FN: ROMANIA
# Sentence: BUCHAREST 1996-08-30
#   FP: BUCHAREST 1996-08-30
#   FN: BUCHAREST
# Sentence: Romania beat Lithuania 2-1 ( halftime 1-1 ) in their European under-21 soccer match on Friday .
#   FP: Friday
# Sentence: Romania - Cosmin Contra ( 31st ) , Mihai Tararache ( 75th )
#   FP: 75th
#   FP: 31st
#   FP: Romania - Cosmin Contra (
#   FN: Romania
#   FN: Cosmin Contra
# Sentence: Lithuania - Danius Gleveckas ( 13rd )
#   FP: 13rd
#   FP: Lithuania - Danius Gleveckas
#   FN: Lithuania
#   FN: Danius Gleveckas
# Sentence: SOCCER - ROTOR FANS LOCKED OUT AFTER VOLGOGRAD VIOLENCE .
#   FN: ROTOR
#   FN: VOLGOGRAD
# Sentence: MOSCOW 1996-08-30
#   FP: 1996-08-30
# Sentence: Rotor Volgograd must play their next home game behind closed doors after fans hurled bottles and stones at Dynamo Moscow players during a 1-0 home defeat on Saturday that ended Rotor 's brief spell as league leaders .
#   FP: Saturday
# Sentence: The head of the Russian league 's disciplinary committee , Anatoly Gorokhovsky , said on Friday that Rotor would play Lada Togliatti to empty stands on September 3 .
#   FP: September 3
#   FP: Russian league 's
#   FP: Friday
#   FN: Russian
# Sentence: The club , who put Manchester United out of last year 's UEFA Cup , were fined $ 1,000 .
#   FP: 1,000
#   FP: last year 's
# Sentence: Despite the defeat , Rotor are well placed with 11 games to play in the championship .
#   FP: 11
# Sentence: Lying three points behind Alania and two behind Dynamo Moscow , the Volgograd side have a game in hand over the leaders and two over the Moscow club .
#   FP: three
#   FP: two
#   FP: two
# Sentence: BOXING - PANAMA 'S ROBERTO DURAN FIGHTS THE SANDS OF TIME .
#   FP: BOXING - PANAMA 'S
#   FN: PANAMA
#   FN: ROBERTO DURAN
# Sentence: PANAMA CITY 1996-08-30
#   FP: 1996-08-30
# Sentence: Panamanian boxing legend Roberto " Hands of Stone " Duran climbs into the ring on Saturday in another age-defying attempt to sustain his long career .
#   FP: Duran
#   FP: Saturday
#   FP: Roberto " Hands of Stone "
#   FN: Roberto " Hands of Stone " Duran
# Sentence: Duran , 45 , takes on little-known Mexican Ariel Cruz , 30 , in a super middleweight non-title bout in Panama City .
#   FP: Mexican Ariel Cruz
#   FP: 45
#   FP: 30
#   FN: Mexican
#   FN: Ariel Cruz
# Sentence: The fight , Duran 's first on home soil for 10 years , is being billed here as the " Return of the Legend " and Duran still talks as if he was in his prime .
#   FP: first
#   FP: 10 years
#   FP: Legend
#   FN: Return of the Legend
# Sentence: If he loses Saturday , it could devalue his position as one of the world 's great boxers , " Panamanian Boxing Association President Ramon Manzanares said .
#   FP: Panamanian Boxing Association
#   FP: Saturday
#   FN: Boxing Association
#   FN: Panamanian
# Sentence: Duran , whose 97-12 record spans three decades , hopes a win in the 10-round bout will earn him a rematch against Puerto Rico 's Hector " Macho " Camacho .
#   FP: three decades
#   FP: Puerto Rico 's
#   FP: 97-12
#   FN: Hector " Macho " Camacho
#   FN: Puerto Rico
# Sentence: Camacho took a controversial points decision against the Panamanian in Atlantic City in June in a title fight .
#   FP: June
# Sentence: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS .
#   FN: HONG KONG OPEN
# Sentence: HONG KONG 1996-08-30
#   FP: 1996-08-30
# Sentence: Quarter-final results in the Hong Kong Open on Friday ( prefix number denotes seeding ) : 1 - Jansher Khan ( Pakistan ) beat Mark Cairns ( England ) 15-10 15-6 15-7
#   FP: the Hong Kong
#   FP: 15-10
#   FP: 15-7
#   FP: Friday
#   FN: Hong Kong Open
#   FN: Jansher Khan
# Sentence: 4 - Peter Nicol ( Scotland ) beat 7 - Chris Walker ( England ) 15-8 15-13 13-15 15-9
#   FP: 15-13
#   FN: Peter Nicol
#   FN: Chris Walker
#   FN: England
# Sentence: 2 - Rodney Eyles ( Australia ) beat Derek Ryan ( Ireland ) 15-6 15-9 11-15 15-10 .
#   FN: Rodney Eyles
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: Pohang 3 Ulsan 2 ( halftime 1-0 )
#   FP: Pohang 3
#   FN: Pohang
#   FN: Ulsan
# Sentence: Puchon 2 Chonbuk 1 ( halftime 1-1 )
#   FP: 2
#   FN: Puchon
#   FN: Chonbuk
# Sentence: Puchon 3 1 0 6 1 10
#   FP: 3 1
#   FN: Puchon
# Sentence: Chonan 3 0 1 13 10 9
#   FP: 3
#   FN: Chonan
# Sentence: Pohang 2 1 1 11 10 7
#   FP: Pohang 2 1 1 11 10 7
#   FN: Pohang
# Sentence: Suwan 1 3 0 7 3 6
#   FP: Suwan 1 3 0 7 3 6
#   FN: Suwan
# Sentence: Ulsan 1 0 2 8 9 3
#   FP: 1
# Sentence: Anyang 0 3 1 6 9 3
#   FN: Anyang
# Sentence: Chonnam 0 2 1 4 5 2
#   FN: Chonnam
# Sentence: Pusan 0 2 1 3 7 2
#   FN: Pusan
# Sentence: Chonbuk 0 0 3 3 7 0
#   FN: Chonbuk
# Sentence: BASEBALL - RESULTS OF S. KOREAN PROFESSIONAL GAMES .
#   FN: S. KOREAN
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: LG 2 OB 0
#   FP: LG 2 OB 0
#   FN: LG
#   FN: OB
# Sentence: Lotte 6 Hyundai 2
#   FP: 2
#   FP: 6
# Sentence: Hyundai 6 Lotte 5
#   FP: 6
# Sentence: Haitai 2 Samsung 0
#   FP: 2
#   FN: Haitai
# Sentence: Samsung 10 Haitai 3
#   FP: 10 Haitai 3
#   FN: Haitai
# Sentence: Hanwha 6 Ssangbangwool 5
#   FP: 6
#   FN: Ssangbangwool
# Sentence: Note - Lotte and Hyundai , Haitai and Samsung played two games .
#   FP: two
#   FN: Lotte
# Sentence: Haitai 64 2 43 .596 -
#   FN: Haitai
# Sentence: Ssangbangwool 59 2 49 .545 5 1/2
#   FP: 5 1/2
#   FN: Ssangbangwool
# Sentence: Hanwha 58 1 49 .542 6
#   FP: 6
#   FP: 58
# Sentence: Hyundai 57 5 49 .536 6 1/2
#   FP: 57 5 49 .536 6 1/2
# Sentence: Samsung 49 5 56 .468 14
#   FP: 49 5
#   FP: 14
# Sentence: Lotte 46 6 54 .462 14 1/2
#   FP: 14 1/2
#   FP: 46 6 54
# Sentence: LG 46 5 59 .441 17
#   FP: 17
#   FP: 46 5 59
#   FN: LG
# Sentence: OB 42 6 62 .409 20 1/2
#   FP: 20 1/2
# Sentence: TENNIS - FRIDAY 'S RESULTS FROM THE U.S. OPEN .
#   FP: U.S.
#   FN: U.S. OPEN
# Sentence: Results from the U.S. Open Tennis Championships at the National Tennis Centre on Friday ( prefix number denotes seeding ) :
#   FP: Friday
#   FP: the National Tennis Centre
#   FN: National Tennis Centre
#   FN: U.S. Open Tennis Championships
# Sentence: Sandrine Testud ( France ) beat Ines Gorrochategui ( Argentina ) 4-6 6-2 6-1
#   FP: 6-1
# Sentence: 4 - Goran Ivanisevic ( Croatia ) beat Scott Draper ( Australia ) 6-7 ( 1-7 ) 6-3 6-4 6-4
#   FP: 1-7
#   FP: 4
#   FN: Australia
# Sentence: Mark Philippoussis ( Australia ) beat Andrei Olhovskiy ( Russia ) 6 - 3 6-4 6-2
#   FP: 6 - 3
# Sentence: Sjeng Schalken ( Netherlands ) beat David Rikl ( Czech Republic ) 6 - 2 6-4 6-4
#   FP: 6 - 2
# Sentence: Guy Forget ( France ) beat 17 - Felix Mantilla ( Spain ) 6-4 7-5 6-3
#   FP: 17
#   FN: Felix Mantilla
# Sentence: Alexander Volkov ( Russia ) beat Mikael Tillstrom ( Sweden ) 1-6 6- 4 6-1 4-6 7-6 ( 10-8 )
#   FP: 10-8
#   FP: 4
# Sentence: Jonas Bjorkman ( Sweden ) beat David Nainkin ( South Africa ) ) 6-4 6-1 6-1
#   FP: 6-4 6-1
# Sentence: 8 - Lindsay Davenport ( U.S. ) beat Anne-Gaelle Sidot ( France ) 6-0 6-3
#   FP: Sidot
#   FP: Davenport
#   FN: Anne-Gaelle Sidot
#   FN: Lindsay Davenport
# Sentence: 4 - Conchita Martinez ( Spain ) beat Helena Sukova ( Czech Republic ) 6-4 6-3
#   FN: Conchita Martinez
# Sentence: Add Men 's singles , second round 16 - Cedric Pioline ( France ) beat Roberto Carretero ( Spain ) 4-6 6 - 2 6-2 6-1 Alex Corretja ( Spain ) beat Filippo Veglio ( Switzerland ) 6-7 ( 4- 7 ) 6-4 6-4 6-0
#   FP: second
#   FP: 16
#   FP: 7
#   FP: 4-6
#   FN: Cedric Pioline
# Sentence: Add Women 's singles , third round Linda Wild ( U.S. ) beat Barbara Rittner ( Germany ) 6-4 4-6 7-5 Asa Carlsson ( Sweden ) beat 15 - Gabriela Sabatini ( Argentina ) 7-5 3-6 6-2
#   FP: 6-4 4-6 7-5 Asa Carlsson
#   FP: 15
#   FP: third
#   FN: Asa Carlsson
#   FN: Gabriela Sabatini
# Sentence: Add Men 's singles , second round 1 - Pete Sampras ( U.S. ) beat Jiri Novak ( Czech Republic ) 6-3 1-6 6-3 4-6 6-4 Paul Haarhuis ( Netherlands ) beat Michael Tebbutt ( Australia ) 1- 6 6-2 6-2 6-3
#   FP: second
#   FP: 6
#   FP: 6-2
#   FN: Pete Sampras
#   FN: Paul Haarhuis
# Sentence: Add Women 's singles , third round Lisa Raymond ( U.S. ) beat Kimberly Po ( U.S. ) 6-3 6-2
#   FP: third
# Sentence: 2 - Monica Seles ( U.S. ) beat Dally Randriantefy ( Madagascar )
#   FP: 2 - Monica Seles
#   FN: Madagascar
#   FN: Monica Seles
# Sentence: Add men 's singles , second round 12 - Todd Martin ( U.S. ) beat Andrea Gaudenzi ( Italy ) 6-3 6-2 6-2 Stefan Edberg ( Sweden ) beat Bernd Karbacher ( Germany ) 3-6 6-3 6-3 1-0 retired ( leg injury )
#   FP: 12
#   FP: second
# Sentence: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S GAMES .
#   FP: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S
#   FN: MAJOR LEAGUE
# Sentence: AMERICAN LEAGUE EASTERN DIVISION
#   FP: AMERICAN LEAGUE EASTERN
#   FN: AMERICAN LEAGUE EASTERN DIVISION
# Sentence: NEW YORK 74 59 .556 -
#   FP: 74 59
#   FN: NEW YORK
# Sentence: BALTIMORE 70 63 .526 4
#   FP: 70 63
# Sentence: BOSTON 69 65 .515 5 1/2
#   FP: 5 1/2
#   FP: 69 65
# Sentence: TORONTO 63 71 .470 11 1/2
#   FP: 11 1/2
#   FP: 63 71
#   FN: TORONTO
# Sentence: DETROIT 48 86 .358 26 1/2
#   FP: 48 86
#   FP: 26 1/2
# Sentence: CENTRAL DIVISION
#   FP: CENTRAL
#   FN: CENTRAL DIVISION
# Sentence: CLEVELAND 80 53 .602 -
#   FP: 53
#   FN: CLEVELAND
# Sentence: CHICAGO 71 64 .526 10
#   FP: 71 64
#   FP: 10
# Sentence: MINNESOTA 67 67 .500 13 1/2
#   FP: 67 67
#   FP: 13 1/2
# Sentence: MILWAUKEE 64 71 .474 17
#   FP: 17
#   FN: MILWAUKEE
# Sentence: KANSAS CITY 61 74 .452 20
#   FP: 20
#   FP: 61 74
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SEATTLE 70 63 .526 5
#   FP: 70 63
# Sentence: OAKLAND 64 72 .471 12 1/2
#   FP: 12 1/2
# Sentence: CALIFORNIA 62 72 .463 13 1/2
#   FP: 62 72 .463
#   FP: 13 1/2
# Sentence: CLEVELAND AT TEXAS
#   FN: CLEVELAND
# Sentence: NATIONAL LEAGUE EASTERN DIVISION
#   FP: NATIONAL LEAGUE EASTERN
#   FN: NATIONAL LEAGUE EASTERN DIVISION
# Sentence: ATLANTA 83 49 .629 -
#   FP: 83 49
# Sentence: MONTREAL 71 61 .538 12
#   FP: 12
#   FP: 71
#   FN: MONTREAL
# Sentence: FLORIDA 64 70 .478 20
#   FP: 20
#   FP: 64 70
# Sentence: NEW YORK 59 75 .440 25
#   FP: 59 75 .440
#   FP: 25
#   FN: NEW YORK
# Sentence: PHILADELPHIA 54 80 .403 30
#   FP: 54 80
#   FP: 30
# Sentence: CENTRAL DIVISION
#   FP: CENTRAL
#   FN: CENTRAL DIVISION
# Sentence: HOUSTON 72 63 .533 -
#   FP: 72 63
# Sentence: ST LOUIS 69 65 .515 2 1/2
#   FP: 69 65 .515
#   FP: 2 1/2
#   FP: ST
#   FN: ST LOUIS
# Sentence: CINCINNATI 66 67 .496 5
#   FP: 66 67 .496
#   FN: CINCINNATI
# Sentence: PITTSBURGH 56 77 .421 15
#   FP: 56 77
#   FP: 15
#   FN: PITTSBURGH
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SAN DIEGO 75 60 .556 -
#   FP: 75 60
#   FN: SAN DIEGO
# Sentence: LOS ANGELES 72 61 .541 2
#   FP: 2
#   FP: 72 61
# Sentence: COLORADO 70 65 .519 5
#   FP: 5
# Sentence: SAN DIEGO AT MONTREAL
#   FN: SAN DIEGO
# Sentence: SAN FRANCISCO AT NEW YORK
#   FN: SAN FRANCISCO
# Sentence: COLORADO AT ST LOUIS
#   FP: ST
#   FN: ST LOUIS
# Sentence: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY .
#   FP: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY
#   FN: MAJOR LEAGUE
# Sentence: DETROIT 4 Kansas City 1
#   FP: 4
# Sentence: Minnesota 6 MILWAUKEE 1
#   FP: 6
#   FN: MILWAUKEE
# Sentence: CALIFORNIA 14 New York 3
#   FP: 3
#   FP: 14
# Sentence: SEATTLE 9 Baltimore 6
#   FP: 9
#   FP: 6
#   FN: Baltimore
# Sentence: San Diego 3 NEW YORK 2
#   FP: 3
#   FN: NEW YORK
# Sentence: Chicago 4 HOUSTON 3
#   FP: 3
#   FN: HOUSTON
# Sentence: Cincinnati 18 COLORADO 7
#   FP: 18
#   FN: COLORADO
# Sentence: Atlanta 5 PITTSBURGH 1
#   FP: 5
#   FP: 1
#   FN: PITTSBURGH
# Sentence: Los Angeles 2 MONTREAL 1
#   FP: Los Angeles 2
#   FP: 1
#   FN: MONTREAL
#   FN: Los Angeles
# Sentence: Florida 10 ST LOUIS 9
#   FP: 10
# Sentence: TENNIS - TARANGO , O'BRIEN SPRING TWIN UPSETS UNDER THE LIGHTS .
#   FP: SPRING TWIN
#   FN: TARANGO
#   FN: O'BRIEN
# Sentence: Andre Agassi escaped disaster on Thursday but Wimbledon finalist MaliVai Washington and Marcelo Rios were not so fortunate on a night of upsets at the U.S. Open .
#   FP: the U.S. Open
#   FP: Thursday
#   FP: a night
#   FN: U.S. Open
# Sentence: The 11th-seeded Washington fell short of reprising his Wimbledon miracle comeback as he lost to red-hot wildcard Alex O'Brien 6-3 6-4 5-7 3-6 6-3 in a two hour 51 minute struggle on the Stadium court .
#   FP: two hour
#   FP: Stadium
#   FP: 6-4 5-7 3-6 6-3
#   FP: 51 minute
#   FP: 11th-seeded

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
# TODO: Write code here to improve the span prediction from Problem 2
pred1 = list()
for row in df_dev.sentence_id.unique():
    sentence = df_dev.loc[df_dev.sentence_id == row, "sentence"].values[0]
    doc = nlp(sentence) 
    for ent in doc.ents:
        if ent.label_ not in ['CARDINAL', 'QUANTITY', 'MONEY', 'PERCENT', 'FAC', 'DATE', 'ORDINAL','TIME']:
            index = row,ent.start, ent.end
            pred1.append(index)

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %%
evaluation_report(spans_dev_gold,set(pred1))
# Out:
# The precision value is 0.8540314136125654
# The recall value is 0.6892006084164273
# The f1 score is 0.762813318368874

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
df1 = df_dev.loc[:,['sentence_id','sentence']].drop_duplicates()

# %%
df2 = pd.DataFrame(columns = ["sentence_id", "sentence", "beg", "end","label"])
for row in df1.itertuples():
    docs = nlp(row[2])
    for entity in docs.ents:
        beg = entity.start
        end = entity.end
        df2.loc[df2.shape[0]+1] = [row[1],row[2],beg,end,'--NME--']

# %%
df2.head(10)
# Out:
#    sentence_id                                           sentence beg end  \
# 1     0946-001                                  LONDON 1996-08-30   0   1
# 2     0946-002  West Indian all-rounder Phil Simmons took four...   0   2
# 3     0946-002  West Indian all-rounder Phil Simmons took four...   3   5
# 4     0946-002  West Indian all-rounder Phil Simmons took four...   6   7
# 5     0946-002  West Indian all-rounder Phil Simmons took four...   8   9
# 6     0946-002  West Indian all-rounder Phil Simmons took four...  10  11
# 7     0946-002  West Indian all-rounder Phil Simmons took four...  12  13
# 8     0946-002  West Indian all-rounder Phil Simmons took four...  19  20
# 9     0946-002  West Indian all-rounder Phil Simmons took four...  22  24
# 10    0946-003  Their stay on top , though , may be short-live...  13  14
#
#       label
# 1   --NME--
# 2   --NME--
# 3   --NME--
# 4   --NME--
# 5   --NME--
# 6   --NME--
# 7   --NME--
# 8   --NME--
# 9   --NME--
# 10  --NME--

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
df3 = df2.copy()
for row in df2.itertuples():
    s = list(row[2].split())
    label = "_".join(s[row[3]:row[4]])
    df3.loc[(df3["sentence_id"]==row[1]) & (df3["beg"]==row[3]) , "label"] = label

# %%
df3.head()
# Out:
#   sentence_id                                           sentence beg end  \
# 1    0946-001                                  LONDON 1996-08-30   0   1
# 2    0946-002  West Indian all-rounder Phil Simmons took four...   0   2
# 3    0946-002  West Indian all-rounder Phil Simmons took four...   3   5
# 4    0946-002  West Indian all-rounder Phil Simmons took four...   6   7
# 5    0946-002  West Indian all-rounder Phil Simmons took four...   8   9
#
#           label
# 1        LONDON
# 2   West_Indian
# 3  Phil_Simmons
# 4          four
# 5            38

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rb') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.
def most_probable_entity(df,ent):
    mentions = df.loc[df["mention"]==ent].sort_values(by=["prob"])
    if mentions.shape[0]>0:
        m = mentions.iloc[0,1]
        return m
    else:
        return "--NME--"

pred2 = []

for ent in df_kb.mention:
    pred2.append(most_probable_entity(df_kb, ent))

# %%
evaluation_report(set(pred2), set(df_kb.mention))
# Out:
# The precision value is 0.03534273906227733
# The recall value is 0.16159860990443092
# The f1 score is 0.058000389787565776

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0    Cup twice the first in @ and the second in 1983
# 1  America 1975 and during the @ and 1978 World C...
# 2                 Manolo represented Spain at the @
# 3  Hašek represented Czechoslovakia at the @ and ...
# 4  renovations in 1989 for the @ The present capa...

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']
# Out:
# 41465    Nebraska Concealed Handgun Permit In @ municip...
# 41466    Lazlo restaurants are located in @ and Omaha C...
# 41467    California Washington Overland Park Kansas @ N...
# 41468    City Missouri Omaha Nebraska and @ Nebraska It...
# 41469    by Sandhills Publishing Company in @ Nebraska USA
#                                ...
# 41609                                      @ Leyton Orient
# 41610                    English division three Swansea @
# 41611    league membership narrowly edging out @ on goa...
# 41612                                          @ Cambridge
# 41613                                                   @
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
mention_list = df_contexts["mention"].unique()
Classifier = {}
for i in mention_list:
    prior_value = df_kb.loc[df_kb.mention == i,:].sort_values(by="entity")["prob"].values
    pipeline = Pipeline([
        ('vect',TfidfVectorizer()),
        ('model',MultinomialNB(class_prior=prior_value))
    ])
    pred3 = pipeline.fit(df_contexts.context[df_contexts["mention"] == i],df_contexts.entity[df_contexts["mention"] == i])
    Classifier[i] = pred3

# %%
Classifier
# Out:
# {'1970': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  '1990 World Cup': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97916667, 0.02083333])))]),
#  '1992': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98571429, 0.01428571])))]),
#  '1996': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.94100295, 0.00294985, 0.0560472 ])))]),
#  '2000 Summer Olympics': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99696878e-01, 3.03122158e-04])))]),
#  '95': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'ABC': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00397803, 0.99602197])))]),
#  'AFL': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99361022, 0.00638978])))]),
#  'AL': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.48780488, 0.51219512])))]),
#  'AL East Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'AR': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.03225806, 0.96774194])))]),
#  'ATLANTA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.13636364, 0.86363636])))]),
#  'AUSTRALIA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'AUSTRALIANS': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'AUSTRIA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'AZ': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.64444444, 0.35555556])))]),
#  'Abu Dhabi': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99695122, 0.00304878])))]),
#  'Academy Award': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01592357, 0.98407643])))]),
#  'Academy Awards': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.002849, 0.997151])))]),
#  'Africa': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.98714157e-01, 1.15725858e-03, 1.28584287e-04])))]),
#  'African': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99270073, 0.00729927])))]),
#  'African American': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.28, 0.72])))]),
#  'Afrikaans': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99864682, 0.00135318])))]),
#  'Air Force': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00271739, 0.99728261])))]),
#  'Airport': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Alaska': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99374870e-01, 6.25130235e-04])))]),
#  'Albania': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99494055e-01, 2.52972426e-04, 2.52972426e-04])))]),
#  'Albanian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([2.75144813e-01, 5.03422854e-01, 2.21169036e-01, 2.63296472e-04])))]),
#  'Albanians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.03267974, 0.96732026])))]),
#  'Algeria': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99812664e-01, 1.87336081e-04])))]),
#  'Algerian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99320190e-01, 6.79809653e-04])))]),
#  'Algiers': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00212089, 0.99787911])))]),
#  'All Blacks': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01, 0.98, 0.01])))]),
#  'Am': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'America': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00122699, 0.00245399, 0.0208589 , 0.97546012])))]),
#  'American': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([7.10765732e-05, 1.18460955e-05, 3.19844579e-04, 1.18460955e-05,
#         1.18460955e-05, 2.81700152e-02, 1.18460955e-05, 2.36921911e-05,
#         2.36921911e-05, 1.18460955e-05, 4.26459439e-04, 1.18460955e-05,
#         9.70491376e-01, 2.36921911e-05, 1.30307051e-04, 2.25075815e-04,
#         1.18460955e-05, 1.18460955e-05])))]),
#  'American Indian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.23195876, 0.76804124])))]),
#  'American Indians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.2761194, 0.7238806])))]),
#  'American League': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99565406e-01, 4.34593655e-04])))]),
#  'American actor': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.16666667, 0.83333333])))]),
#  'American born': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02777778, 0.97222222])))]),
#  'Americans': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.54506438, 0.45493562])))]),
#  'Americas': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Ancient Roman': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.75, 0.25])))]),
#  'Ancient Rome': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Andersson': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Andy': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Anglo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00862069, 0.56034483, 0.00862069, 0.06896552, 0.35344828])))]),
#  'Anglo Irish': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.33333333, 0.33333333])))]),
#  'Anglo Welsh': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Angola': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99370208, 0.00629792])))]),
#  'Antwerp': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99006796, 0.00993204])))]),
#  'Arab': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.40462428, 0.1849711 , 0.01734104, 0.39306358])))]),
#  'Arabian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Arabian Gulf': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Arabic': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.45665962e-04, 9.95771670e-01, 3.38266385e-03])))]),
#  'Arabs': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01136364, 0.98863636])))]),
#  'Armed Forces': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Armenia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99577227, 0.00422773])))]),
#  'Army': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([3.85356455e-03, 9.63391137e-04, 9.95183044e-01])))]),
#  'Arrows': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Asia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.49566258e-04, 9.99850434e-01])))]),
#  'Athens': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([3.35739466e-04, 9.99664261e-01])))]),
#  'Atlanta': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00609385, 0.99116392, 0.00274223])))]),
#  'Atlanta Georgia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01041667, 0.98958333])))]),
#  'Auckland': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99776119, 0.00223881])))]),
#  'Australia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.79969034e-01, 1.66924715e-03, 9.38649119e-03, 8.83007548e-03,
#         2.41919876e-05, 9.67679505e-05, 2.41919876e-05])))]),
#  'Australia national rugby union team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.03174603, 0.96825397])))]),
#  'Australian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.60891591e-01, 6.75447484e-05, 2.70178994e-03, 8.78081729e-04,
#         4.05268490e-04, 3.50557244e-02])))]),
#  'Australian Football League': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99651568e-01, 3.48432056e-04])))]),
#  'Australian Rules Football': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Australian national side': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.875, 0.125])))]),
#  'Australian national team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.4, 0.6])))]),
#  'Australian rules football': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([3.76364321e-04, 9.99623636e-01])))]),
#  'Australians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.1761658 , 0.00518135, 0.66839378, 0.15025907])))]),
#  'Austria': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.73848950e-01, 7.06785137e-04, 1.51453958e-02, 8.07754443e-04,
#         9.28917609e-03, 2.01938611e-04])))]),
#  'Austrian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.95478417e-01, 5.12360702e-04, 1.75483540e-02, 8.64608685e-02])))]),
#  'Austrian American': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Austrian born': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.77777778, 0.22222222])))]),
#  'Austrians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.53658537, 0.12195122, 0.34146341])))]),
#  'Austro': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.70588235, 0.11764706, 0.17647059])))]),
#  'Azerbaijan': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99668705, 0.00331295])))]),
#  'BALTIMORE': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.14285714, 0.85714286])))]),
#  'BARCELONA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'BOSTON': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.16666667, 0.83333333])))]),
#  'BSE': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.96551724, 0.03448276])))]),
#  'Baghdad': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99728445, 0.00271555])))]),
#  'Baltimore': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99031477, 0.00968523])))]),
#  'Baltimore Orioles': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.96811398, 0.03188602])))]),
#  'Barcelona': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00287301, 0.9254932 , 0.07163379])))]),
#  'Barry': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.99, 0.01])))]),
#  'Basque': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.6185567, 0.3814433])))]),
#  'Basque Country': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.86926829, 0.13073171])))]),
#  'Basque Region': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Basque country': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Beijing': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99074217e-01, 4.62891529e-04, 4.62891529e-04])))]),
#  'Belarus': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99258649, 0.00741351])))]),
#  'Belarusian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99285204e-01, 7.14796283e-04])))]),
#  'Belgian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.83654729e-04, 9.99081726e-01, 3.67309458e-04, 1.83654729e-04,
#         1.83654729e-04])))]),
#  'Belgium': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.75729712e-01, 9.62258099e-04, 2.30941944e-02, 1.06917567e-04,
#         1.06917567e-04])))]),
#  'Benetton': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97540984, 0.02459016])))]),
#  'Bengal': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.14285714, 0.85714286])))]),
#  'Berlin': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.06826194e-04, 9.99679521e-01, 2.13652388e-04])))]),
#  'Biblical': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99421965, 0.00578035])))]),
#  'Birmingham': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.91388692, 0.08516678, 0.0009463 ])))]),
#  'Bohemian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Bordeaux': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.90081893, 0.09918107])))]),
#  'Bosnia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.36713287, 0.63286713])))]),
#  'Bosnia and Herzegovina': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99849579e-01, 1.50421179e-04])))]),
#  'Bosnian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01978417, 0.98021583])))]),
#  'Bosnian Serb': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.9375, 0.0625])))]),
#  'Boston': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99761526, 0.00238474])))]),
#  'Botham': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Botswana': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98998498, 0.01001502])))]),
#  'Bradford': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.84782609, 0.15217391])))]),
#  'Brady': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.71428571, 0.28571429])))]),
#  'Brazil': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.85236473e-01, 1.44704546e-02, 3.66340624e-05, 2.56438436e-04])))]),
#  'Brazilian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.98534881e-01, 1.12701454e-03, 3.38104362e-04])))]),
#  'Bremen': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Brisbane': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99120412, 0.00242645, 0.00636943])))]),
#  'Bristol': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99614049e-01, 3.85951370e-04])))]),
#  'Britain': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([7.59301443e-04, 2.27790433e-03, 9.96962794e-01])))]),
#  'British': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([3.80126962e-05, 3.80126962e-05, 1.02938381e-01, 3.80126962e-05,
#         5.16972669e-03, 7.60253925e-05, 7.60253925e-05, 7.60253925e-05,
#         3.80126962e-05, 3.80126962e-05, 3.80126962e-05, 8.91245676e-01,
#         1.52050785e-04, 3.80126962e-05])))]),
#  'British Columbia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99917594e-01, 8.24062629e-05])))]),
#  'British India': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.33333333, 0.33333333])))]),
#  'British Open': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01449275, 0.98550725])))]),
#  'British born': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.15384615, 0.15384615, 0.69230769])))]),
#  'Britishers': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Briton': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.65217391, 0.34782609])))]),
#  'Britons': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.06666667, 0.26666667])))]),
#  'Brooklyn Bridegrooms': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02564103, 0.97435897])))]),
#  'Buenos Aires': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.94967856, 0.05032144])))]),
#  'Bulgaria': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.83032360e-01, 1.62404557e-02, 7.27184584e-04])))]),
#  'Bulgarian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.98415393e-01, 5.65930956e-04, 1.01018676e-01])))]),
#  'Bulgarians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.04945055, 0.95054945])))]),
#  'Bulldogs': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.84, 0.16])))]),
#  'Burundi': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99435737, 0.00564263])))]),
#  'CHICAGO': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.37288136, 0.03389831, 0.59322034])))]),
#  'CLEVELAND': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.1, 0.9])))]),
#  'CSKA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.1, 0.9])))]),
#  'Cabinet': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98780488, 0.01219512])))]),
#  'Cairo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99500250e-01, 4.99750125e-04])))]),
#  'California': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99736634e-01, 1.64603634e-04, 9.87621807e-05])))]),
#  'Cambodia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99628253e-01, 3.71747212e-04])))]),
#  'Cambodian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.95800525, 0.04199475])))]),
#  'Cambodians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.77777778, 0.22222222])))]),
#  'Cambridge': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97586207, 0.02413793])))]),
#  'Cameroon': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98333038, 0.01666962])))]),
#  'Cameroonian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99570815, 0.00429185])))]),
#  'Canadian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99891087e-01, 3.63042294e-05, 3.63042294e-05, 3.63042294e-05])))]),
#  'Canadian province': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'Canberra': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([6.67111408e-04, 9.93328886e-01, 6.00400267e-03])))]),
#  'Canton': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.09917355, 0.90082645])))]),
#  'Cantonese': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.33333333, 0.33333333])))]),
#  'Cardiff': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.9397482 , 0.00494604, 0.05530576])))]),
#  'Caribbean island': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Celtic': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99042146e-01, 9.57854406e-04])))]),
#  'Central': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.25862069, 0.70689655, 0.01724138, 0.01724138])))]),
#  'Central African Republic': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99630314, 0.00369686])))]),
#  'Central Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.46428571, 0.53571429])))]),
#  'Ceylon': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.88157895, 0.11842105])))]),
#  'Champions League': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00858369, 0.99141631])))]),
#  'Championship': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.875, 0.125])))]),
#  'Charleroi': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.75572519, 0.24427481])))]),
#  'Charles': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.84615385, 0.15384615])))]),
#  'Charleston': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.70699433, 0.29300567])))]),
#  'Chechen': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.20792079, 0.79207921])))]),
#  'Chechens': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.78378378, 0.21621622])))]),
#  'Chelsea': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00580833, 0.99419167])))]),
#  'Chester le Street': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98165138, 0.01834862])))]),
#  'Chesterfield': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.38636364, 0.61237374, 0.00126263])))]),
#  'Chicago': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.98935377e-01, 2.12924518e-04, 1.06462259e-04, 7.45235814e-04])))]),
#  'Chicago White Stockings': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.94202899, 0.05797101])))]),
#  'Chile': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97850189, 0.02149811])))]),
#  'China': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99605086e-01, 3.15930811e-04, 7.89827028e-05])))]),
#  'Chinese': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.32596154e-01, 7.86394231e-01, 8.08173077e-02, 4.80769231e-05,
#         1.44230769e-04])))]),
#  'Chinese government': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'Chinese national': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'Christian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.71428571, 0.28571429])))]),
#  'Christianity': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Church': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02040816, 0.97959184])))]),
#  'Church of Rome': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Cincinnati': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98510972, 0.01489028])))]),
#  'City': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.0625, 0.0625, 0.125 , 0.25  , 0.0625, 0.1875, 0.0625, 0.0625,
#         0.0625, 0.0625])))]),
#  'City of Charleston': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Cleveland': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98842018, 0.01157982])))]),
#  'Club': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.75, 0.25])))]),
#  'Colchester': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00680272, 0.96825397, 0.02494331])))]),
#  'Collins': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.91666667, 0.08333333])))]),
#  'Cologne': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00480513, 0.99519487])))]),
#  'Colombo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.42459983e-04, 9.99157540e-01])))]),
#  'Colorado': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99329646e-01, 6.70353612e-04])))]),
#  'Commission on Human Rights': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.09090909, 0.90909091])))]),
#  'Common Market': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.75, 0.25])))]),
#  'Commonwealth': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.51438667e-03, 9.59111560e-03, 9.86370520e-01, 1.00959112e-03,
#         5.04795558e-04, 1.00959112e-03])))]),
#  'Commonwealth Games': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99867198, 0.00132802])))]),
#  'Communist': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.9047619, 0.0952381])))]),
#  'Communist China': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Communist government': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Communist party': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.03571429, 0.96428571])))]),
#  'Communist regime': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Communists': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.95238095, 0.04761905])))]),
#  'Congo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.07964602, 0.61946903, 0.30088496])))]),
#  'Congolese': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.54011742, 0.45988258])))]),
#  'Congress': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00726392, 0.00363196, 0.98910412])))]),
#  'Congressman': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.015625, 0.984375])))]),
#  'Continental': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.08333333, 0.75      , 0.16666667])))]),
#  'Costa Rica': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98624564, 0.01375436])))]),
#  'Council': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.1, 0.9])))]),
#  'Country': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.33333333, 0.33333333])))]),
#  'Crawley': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99069767, 0.00930233])))]),
#  'Croat': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.90909091, 0.09090909])))]),
#  'Croatia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.984525  , 0.00128958, 0.01303912, 0.0011463 ])))]),
#  'Croatian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99534451, 0.00217256, 0.00248293])))]),
#  'Croatian team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Crvena Zvezda': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Crvena zvezda': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.95, 0.05])))]),
#  'Crystal Palace': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00143062, 0.0472103 , 0.95135908])))]),
#  'Cuba': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99190939, 0.00809061])))]),
#  'Cuban': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99329759e-01, 6.70241287e-04])))]),
#  'Cup': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.4, 0.6])))]),
#  'Cyprus': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98717566, 0.01282434])))]),
#  'Czech': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([2.95857988e-04, 9.99112426e-01, 5.91715976e-04])))]),
#  'Czech Republic': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.84934946e-01, 1.25542114e-03, 3.42387583e-04, 1.34672449e-02])))]),
#  'Czechoslovakia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.125, 0.75 , 0.125])))]),
#  'DR Congo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.21568627, 0.78431373])))]),
#  'DUTCH': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.92857143, 0.07142857])))]),
#  'Dakotas': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Damascus': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99539595, 0.00460405])))]),
#  'David': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99603175, 0.00396825])))]),
#  'Davis Cup': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00234192, 0.99765808])))]),
#  'Dayton': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97610922, 0.02389078])))]),
#  'Dean': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Democrat': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00220913, 0.99779087])))]),
#  'Democratic': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.57548675e-04, 9.98563677e-01, 3.19182892e-04, 1.59591446e-04])))]),
#  'Democratic Party': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02222222, 0.97777778])))]),
#  'Democratic Republic of the Congo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([2.72257011e-04, 9.99727743e-01])))]),
#  'Democrats': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02474227, 0.97525773])))]),
#  'Denver': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.69565217e-04, 9.99130435e-01])))]),
#  'Detroit': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99358974, 0.00641026])))]),
#  'Dhaka': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99709302, 0.00290698])))]),
#  'Dow': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Dresden': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99389126e-01, 6.10873549e-04])))]),
#  'Ducati': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.53333333, 0.46666667])))]),
#  'Dundee': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99593496, 0.00406504])))]),
#  'Durban': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99891658, 0.00108342])))]),
#  'Dutch': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.13934560e-05, 1.02718541e-01, 2.44180368e-04, 8.96630311e-01,
#         3.25573824e-04])))]),
#  'Dutch born': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.125, 0.875])))]),
#  'Dutch football team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Dutchman': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.47368421, 0.52631579])))]),
#  'Dynamo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.22222222, 0.66666667, 0.11111111])))]),
#  'Dynamo Moscow': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.04477612, 0.95522388])))]),
#  'EC': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.38461538, 0.61538462])))]),
#  'ECOMOG': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.2, 0.8])))]),
#  'ENG': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'ENGLAND': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.28571429, 0.61904762, 0.04761905, 0.04761905])))]),
#  'ESSEX': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'EU': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00601504, 0.99398496])))]),
#  'East': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.12121212, 0.66666667, 0.06060606, 0.03030303, 0.09090909,
#         0.03030303])))]),
#  'East Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.71428571, 0.28571429])))]),
#  'East German': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98446069, 0.01553931])))]),
#  'Eastern': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Eastern Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.06451613, 0.93548387])))]),
#  'Edgbaston': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.47265625, 0.52734375])))]),
#  'Egyptian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.75241313, 0.24758687])))]),
#  'Egyptian born': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Egyptians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.26136364, 0.73863636])))]),
#  'Eight years later': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.33333333, 0.16666667, 0.16666667])))]),
#  'Elizabeth': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.1862069, 0.8137931])))]),
#  'Emirate': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'Emperor': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Emperor Napoleon': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.8, 0.2])))]),
#  'Empire': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02597403, 0.02597403, 0.92207792, 0.01298701, 0.01298701])))]),
#  'England': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.91703090e-05, 9.33018940e-01, 1.47036270e-02, 2.69342842e-02,
#         1.91511387e-02, 1.91703090e-05, 5.17598344e-03, 1.53362472e-04,
#         1.91703090e-05, 8.05152979e-04])))]),
#  'England International': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.8, 0.2])))]),
#  'England and Wales': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'England international': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.92592593, 0.07407407])))]),
#  'England national cricket team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'England national rugby union team': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01162791, 0.98837209])))]),
#  'England national side': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.75, 0.25])))]),
#  'England national team': Pipeline(steps=[('vect', TfidfVectorizer()),
# ...
#                  ('model',
#                   MultinomialNB(class_prior=array([7.46268657e-04, 9.99253731e-01])))]),
#  'Telfer': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'Texas': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([5.58846541e-05, 9.99329384e-01, 5.58846541e-05, 5.58846541e-04])))]),
#  'The City': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'The Netherlands': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98113208, 0.01886792])))]),
#  'The Oval': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00292398, 0.99707602])))]),
#  'The Telegraph': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'The Vatican': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.85714286, 0.14285714])))]),
#  'Tigers': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.04761905, 0.26190476, 0.02380952, 0.66666667])))]),
#  'Times': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02222222, 0.97777778])))]),
#  'Togo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98515326, 0.01484674])))]),
#  'Togolese': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.9954955, 0.0045045])))]),
#  'Tokyo': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99878641, 0.00121359])))]),
#  'Tony': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.6, 0.2, 0.2])))]),
#  'Torino': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.94674556, 0.05325444])))]),
#  'Toronto': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99051633e-01, 9.48366702e-04])))]),
#  'Tour': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.81818182, 0.18181818])))]),
#  'Toyota': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99722222, 0.00277778])))]),
#  'Treasury': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97368421, 0.02631579])))]),
#  'Tunbridge Wells': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02564103, 0.97435897])))]),
#  'Tunis': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99853587, 0.00146413])))]),
#  'Tunisia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97129784, 0.02870216])))]),
#  'Tunisian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01070336, 0.97400612, 0.01529052])))]),
#  'Turkey': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00775194, 0.99224806])))]),
#  'Turkish': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.14285714, 0.42857143, 0.42857143])))]),
#  'Turkish Cypriot': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.05555556, 0.94444444])))]),
#  'U21': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'UEFA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99005964e-01, 9.94035785e-04])))]),
#  'UEFA Cup': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00680272, 0.99319728])))]),
#  'UK': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([4.80192077e-04, 1.20048019e-03, 2.40096038e-04, 9.98079232e-01])))]),
#  'US': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([3.75657400e-04, 3.75657400e-04, 6.66791886e-01, 3.75657400e-04,
#         3.75657400e-04, 3.31329827e-01, 3.75657400e-04])))]),
#  'US Open': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00378788, 0.00378788, 0.99242424])))]),
#  'US President': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'US state': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.14285714, 0.85714286])))]),
#  'USA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.25770343e-04, 9.93837253e-01, 6.03697648e-03])))]),
#  'USN': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01111111, 0.98888889])))]),
#  'Uganda': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99379845, 0.00620155])))]),
#  'Ukraine': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99289645, 0.00710355])))]),
#  'Ukrainian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99399580e-01, 6.00420294e-04])))]),
#  'Ulsan': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.98445596, 0.01554404])))]),
#  'Under 21': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.1, 0.3, 0.6])))]),
#  'Union': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.03225806, 0.01612903, 0.01612903, 0.90322581, 0.01612903,
#         0.00806452, 0.00806452])))]),
#  'United': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.05882353, 0.35294118, 0.05882353, 0.52941176])))]),
#  'United Kingdom': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([4.25224306e-05, 4.25224306e-05, 4.25224306e-05, 9.99872433e-01])))]),
#  'United Nations': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99809124e-01, 1.90876121e-04])))]),
#  'United States': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([7.85478081e-06, 3.14191232e-05, 7.85478081e-06, 1.57095616e-05,
#         7.85478081e-06, 7.85478081e-06, 9.99355908e-01, 2.35643424e-05,
#         7.85478081e-05, 7.85478081e-06, 7.85478081e-06, 3.53465137e-04,
#         7.85478081e-05, 1.57095616e-05])))]),
#  'United States Army': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.45243282e-04, 9.99854757e-01])))]),
#  'United States of America': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99806202, 0.00193798])))]),
#  'University of Oxford': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([8.44238075e-04, 9.99155762e-01])))]),
#  'Va': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.8, 0.2])))]),
#  'Vaduz': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.20930233, 0.01162791, 0.77906977])))]),
#  'Valletta': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.87460815, 0.12539185])))]),
#  'Vasco da Gama': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.01041667, 0.98958333])))]),
#  'Vatican': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00308642, 0.96296296, 0.03395062])))]),
#  'Venice': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99710669, 0.00289331])))]),
#  'Verona': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.06056701, 0.93943299])))]),
#  'Victoria': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([2.91885581e-04, 9.99708114e-01])))]),
#  'Victorian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00914634, 0.99085366])))]),
#  'Vienna': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.49925037e-04, 9.99850075e-01])))]),
#  'Vietnam': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.97619674, 0.02380326])))]),
#  'Virginia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.99796996e-01, 2.03004466e-04])))]),
#  'Volkswagen': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.99259259, 0.00740741])))]),
#  'Volkswagen AG': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.16666667, 0.83333333])))]),
#  'WA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.7037037, 0.2962963])))]),
#  'WBA': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Wales': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.95077039, 0.04763247, 0.00159714])))]),
#  'Wales Under 21': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.25, 0.75])))]),
#  'Wall': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Wall Street': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02099738, 0.97900262])))]),
#  'War': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.05263158, 0.10526316, 0.84210526])))]),
#  'Warrior': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Washington': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([9.05633037e-05, 3.62253215e-04, 4.52816519e-04, 4.52816519e-04,
#         6.33943126e-04, 7.76942583e-01, 2.21065024e-01])))]),
#  'Washington Senators': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.81576535, 0.18423465])))]),
#  'Welsh': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00157828, 0.98705808, 0.01136364])))]),
#  'Wembley': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.05405405, 0.94594595])))]),
#  'West': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.2866242 , 0.00636943, 0.02547771, 0.00636943, 0.67515924])))]),
#  'West Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.47368421, 0.52631579])))]),
#  'West German': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.04347826, 0.39130435, 0.04347826, 0.52173913])))]),
#  'West Germany': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.07638889, 0.05555556, 0.03472222, 0.83333333])))]),
#  'West Indian': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02255639, 0.09022556, 0.88721805])))]),
#  'West Indians': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00990099, 0.99009901])))]),
#  'West Indies': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.02008032, 0.07630522, 0.90361446])))]),
#  'West division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.42857143, 0.57142857])))]),
#  'Western': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.00425532, 0.00851064, 0.00425532, 0.04255319, 0.01276596,
#         0.92765957])))]),
#  'Western Australia': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([1.40508641e-04, 9.99859491e-01])))]),
#  'Western Division': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.38888889, 0.61111111])))]),
#  'Western Divisions': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model', MultinomialNB(class_prior=array([0.5, 0.5])))]),
#  'Western Europe': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.66666667, 0.33333333])))]),
#  'Weston super Mare': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.04522613, 0.95477387])))]),
#  'Wien': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.33333333, 0.66666667])))]),
#  'Wigan': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.48172043, 0.00967742, 0.50860215])))]),
#  'Williams': Pipeline(steps=[('vect', TfidfVectorizer()),
#                  ('model',
#                   MultinomialNB(class_prior=array([0.06666667, 0.93333333])))]),
#  ...}

# %%
df4 = df2.copy()
labels = []
for row in df2.itertuples():
    sentence = row[2]
    beg = row[3]
    end = row[4]
    mention = row[5]
    if mention in Classifier:
        Class = Classifier[mention]
        label = Class.predict(sentence)[0]
    elif mention in list(df_kb["mention"]):
        label = df_kb.loc[df_kb.mention==mention,"entity"].values[0]
    else:
        label = "--NME--"
    labels.append(label)
df4["labels"] = labels

# %%
pred4 = gold_mentions(df4)
gold = gold_mentions(df_dev)

# %%
evaluation_report(set(gold), set(pred4))
# Out:
# The precision value is 0.08394160583941605
# The recall value is 0.10883893865134359
# The f1 score is 0.09478254470527632

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions are questions that you could be asked in the oral exam. Try to answer each of them in the form of a short text and enter it in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
